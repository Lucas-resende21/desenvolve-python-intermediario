# %% [markdown]
# > Projeto Desenvolve <br>
# Programação Intermediária com Python <br>
# Profa. Camila Laranjeira (mila@projetodesenvolve.com.br) <br>
#
# # 3.9 - Visualização de Dados

# %% [markdown]
# ## Exercícios
# Vamos trabalhar com as mesmas bases de dados do exercício de Pandas. Aqui estão os links caso você queira baixar novamente, mas recomendo trabalhar com o `wc_formatado.csv` que exportamos na questão Q2 do exercício anterior.
#
# * https://raw.githubusercontent.com/camilalaranjeira/python-intermediario/main/fifa-wc/matches_1930_2022.csv
# * https://raw.githubusercontent.com/camilalaranjeira/python-intermediario/main/fifa-wc/matches_1991_2023.csv
#
# Para relembrar, essas são as colunas do dataframe:
# ```
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   time_1             1312 non-null   string
#  1   time_2             1312 non-null   string
#  2   gols_1             1312 non-null   int64
#  3   gols_2             1312 non-null   int64
#  4   data               1312 non-null   datetime64[ns]
#  5   ano                1312 non-null   int64
#  6   país_sede          1312 non-null   string
#  7   comparecimento     1312 non-null   int64
#  8   resultado          1312 non-null   string
#  9   rodada             1312 non-null   category
#  10  gols_1_detalhes    970 non-null    string
#  11  gols_2_detalhes    771 non-null    string
#  12  gols_1_contra      57 non-null     string
#  13  gols_2_contra      30 non-null     string
#  14  gols_1_penalti     170 non-null    string
#  15  gols_2_penalti     119 non-null    string
#  16  cartao_vermelho_1  59 non-null     string
#  17  cartao_vermelho_2  65 non-null     string
#  18  cartao_amarelo_1   834 non-null    string
#  19  cartao_amarelo_2   857 non-null    string
#  20  copa               1312 non-null   string
# ```

# %% [markdown]
# #### Q1.
# Realize todos os imports necessários para executar as três bibliotecas de visualização que conhecemos:
# * Matplotlib (lembre-se do comando mágico)
# * Seaborn
# * Plotly
#
# Para cada uma delas, altere o tema padrão de visualização.

# %%
# 1. Matplotlib: A biblioteca base para gráficos em Python
import matplotlib.pyplot as plt
# Comando mágico para exibir gráficos diretamente no Jupyter/Google Colab
# %matplotlib inline 
# Alterando o tema padrão para um estilo limpo e moderno
plt.style.use('ggplot') 

# 2. Seaborn: Baseada no Matplotlib, excelente para visualizações estatísticas
import seaborn as sns
# Alterando o tema para um fundo escuro com grade, ideal para dashboards
sns.set_theme(style="darkgrid", palette="muted")

# 3. Plotly: Ideal para gráficos interativos e web (muito usado em Dashboards)
import plotly.express as px
import plotly.io as pio
# Alterando o tema padrão para o modo 'plotly_white' (fundo branco, visual profissional)
pio.templates.default = "plotly_white"

# %% [markdown]
# #### Q2.
# Sobre os dados de copa do mundo, qual a distribuição de público presente nos jogos? Isso pode ser respondido com um histograma com os dados da coluna `comparecimento`.
#
# Lembre-se que alguns jogos estavam com público 0 incorretamente, que tal remover essas ocorrências para não atrapalhar sua visualzação?
#
# Você deve implementar essa visualização nas três bibliotecas que vimos:
# * Matplotlib
# * Seaborn
# * Plotly
#
# Garanta que o gráfico tenha pelo menos os atributos de título e rótulos de dimensão.

# %%
#### Solução com matplotlib
# Matplotlib
df_filtrado = wc[wc['comparecimento'] > 0]
plt.figure(figsize=(10, 6))
plt.hist(df_filtrado['comparecimento'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribuição de Público nos Jogos da Copa do Mundo')
plt.xlabel('Público Presente')
plt.ylabel('Frequência de Jogos')
plt.show()

# %%
#### solução com seaborn
# Seaborn
df_filtrado = wc[wc['comparecimento'] > 0]
plt.figure(figsize=(10, 6))
sns.histplot(df_filtrado['comparecimento'], bins=30, kde=True, color='teal')
plt.title('Distribuição de Público nos Jogos da Copa do Mundo')
plt.xlabel('Público Presente')
plt.ylabel('Frequência de Jogos')
plt.show()

# %%
#### solução com plotly
# Plotly
df_filtrado = wc[wc['comparecimento'] > 0]
fig = px.histogram(df_filtrado, x='comparecimento', nbins=30,
                   title='Distribuição de Público nos Jogos da Copa do Mundo',
                   labels={'comparecimento': 'Público Presente', 'count': 'Frequência de Jogos'})
fig.show()

# %% [markdown]
# #### Q3.
#
# Apresente um gráfico de dispersão (scatter) dos atributos `gols_1` e `gols_2`. Isso representa a relação entre gols feitos e gols tomados por jogo. Há alguma relação interessante entre esses atributos?
#
# Para facilitar a visualização dos dados (já que tem muitos placares repetidos), aplique uma leve distorção aos dados para que cada ponto esteja deslocado aleatoriamente de seu valor original. Código apresentado a seguir
# ```python
# gols = wc[['gols_1', 'gols_2']] * np.random.random((len(wc),2))
# ```
#
# Você deve implementar essa visualização nas três bibliotecas que vimos:
# * Matplotlib
# * Seaborn
# * Plotly
#
# Garanta que o gráfico tenha pelo menos os atributos de título e rótulos de dimensão.

# %%
#### solução com matplotlib
# Matplotlib
import numpy as np
gols_distorcidos = wc[['gols_1', 'gols_2']] + (np.random.rand(len(wc), 2) - 0.5) * 0.5

plt.figure(figsize=(10, 6))
plt.scatter(gols_distorcidos['gols_1'], gols_distorcidos['gols_2'], alpha=0.5, color='purple')
plt.title('Relação entre Gols do Time 1 e Time 2 (Dispersão com Jitter)')
plt.xlabel('Gols do Time 1')
plt.ylabel('Gols do Time 2')
plt.show()

# %%
#### solução com seaborn
# Seaborn
import numpy as np
gols_distorcidos = wc[['gols_1', 'gols_2']] + (np.random.rand(len(wc), 2) - 0.5) * 0.5

plt.figure(figsize=(10, 6))
sns.scatterplot(x=gols_distorcidos['gols_1'], y=gols_distorcidos['gols_2'], alpha=0.5, color='darkcyan')
plt.title('Relação entre Gols do Time 1 e Time 2 (Dispersão com Jitter)')
plt.xlabel('Gols do Time 1')
plt.ylabel('Gols do Time 2')
plt.show()

# %%
#### solução com plotly
# Plotly
import numpy as np
gols_distorcidos = wc[['gols_1', 'gols_2']].copy()
gols_distorcidos['gols_1_j'] = wc['gols_1'] + (np.random.rand(len(wc)) - 0.5) * 0.5
gols_distorcidos['gols_2_j'] = wc['gols_2'] + (np.random.rand(len(wc)) - 0.5) * 0.5

fig = px.scatter(gols_distorcidos, x='gols_1_j', y='gols_2_j', opacity=0.5,
                 title='Relação entre Gols do Time 1 e Time 2 (Dispersão com Jitter)',
                 labels={'gols_1_j': 'Gols do Time 1', 'gols_2_j': 'Gols do Time 2'})
fig.show()

# %% [markdown]
# #### Q4.
#
# Apresente um gráfico de barras com o top 10 países que mais participaram de copas do mundo, onde no eixo x devem estar o nome dos países e no eixo y a contagem de participações. Você deve separar a contagem de participações em copas femininas e masculinas, empilhando as barras de cada informação.
#
# No exemplo de barras empilhadas da galeria do matplotlib, imagine que a parte azul são as participações do país em copas masculinas, e em laranja as participações femininas:
# * https://matplotlib.org/stable/gallery/lines_bars_and_markers/bar_stacked.html
#
# Você deve implementar essa visualização nas três bibliotecas que vimos:
# * Matplotlib
# * Seaborn
# * Plotly
#
# Garanta que o gráfico tenha pelo menos os atributos:
# * título
# * rótulos de dimensão.
# * legenda

# %%
#### solução com matplotlib
# Matplotlib
df_pivot = participacao.pivot(index='país', columns='copa', values='num_copas').fillna(0)
df_pivot['total'] = df_pivot.sum(axis=1)
top_10 = df_pivot.sort_values(by='total', ascending=False).head(10)

plt.figure(figsize=(12, 6))
plt.bar(top_10.index, top_10['Masculina'], label='Masculina', color='royalblue')
plt.bar(top_10.index, top_10['Feminina'], bottom=top_10['Masculina'], label='Feminina', color='orange')
plt.title('Top 10 Países com Mais Participações em Copas (Empilhado)')
plt.xlabel('País')
plt.ylabel('Número de Participações')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
#### solução com seaborn
# Seaborn
top_10_lista = participacao.groupby('país')['num_cartões amarelos'].sum().nlargest(10).index # Errata: Use o ranking da soma total
df_top10_long = participacao[participacao['país'].isin(top_10.index)]

plt.figure(figsize=(12, 6))
sns.histplot(data=df_top10_long, x='país', weights='num_copas', hue='copa', multiple='stack', shrink=0.8, palette={'Masculina': 'royalblue', 'Feminina': 'orange'})
plt.title('Top 10 Países com Mais Participações em Copas (Empilhado)')
plt.xlabel('País')
plt.ylabel('Número de Participações')
plt.xticks(rotation=45)
plt.show()

# %%
#### solução com plotly
# Plotly
df_top10_plotly = participacao[participacao['país'].isin(top_10.index)].copy()
df_top10_plotly = df_top10_plotly.sort_values(by='país', key=lambda x: x.map({v: i for i, v in enumerate(top_10.index)}))

fig = px.bar(df_top10_plotly, x='país', y='num_copas', color='copa',
             title='Top 10 Países com Mais Participações em Copas (Empilhado)',
             labels={'num_copas': 'Número de Participações', 'país': 'País', 'copa': 'Competição'},
             color_discrete_map={'Masculina': 'royalblue', 'Feminina': 'orange'},
             barmode='stack')
fig.show()

# %% [markdown]
# #### Q5.
#
# Vamos fazer um compilado com as estatísticas históricas de copas do mundo!
#
# Com a biblioteca de sua preferência você deve criar 4 subplots organizados em um grid de 2 linhas e 2 colunas. Eles devem conter os seguintes gráficos:
# * Linha 1, coluna 1: Gráfico de barras com a quantidade de jogos que aconteceram por ano
# * Linha 1, coluna 2: Gráfico de área (referências a seguir) com o total de gols por ano, separando as informações de `gols_1` e `gols_2` para distinguir gols em casa e do time visitante.
# * Linha 2, coluna 1: Gráfico de área com o total de cartões por ano, separando as informações de cartões amarelos e cartões vermelhos, mas agregando cartões do time 1 ou time 2. Ou seja, uma área com `cartao_amarelo_1 + cartao_amarelo_2` e outra área com `cartao_vermelho_1 + cartao_vermelho_2`.
# * Linha 2, coluna 2: Gráfico de barras com o total de gols contra por ano, somando `gols_contra_1` e `gols_contra_2`.
#
# Referências sobre gráfico de área
# * Matplotlib: https://matplotlib.org/stable/gallery/lines_bars_and_markers/stackplot_demo.html#sphx-glr-gallery-lines-bars-and-markers-stackplot-demo-py
# * Pandas + Matplotlib: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.area.html
# * Seaborn: https://seaborn.pydata.org/generated/seaborn.objects.Area.html
# * Plotly: https://plotly.com/python/filled-area-plots/

# %%
import matplotlib.pyplot as plt

jogos_ano = wc.groupby('ano').size()

gols_ano = wc.groupby('ano')[['gols_1', 'gols_2']].sum()

def extrair_contagem(valor):
    if pd.isna(valor) or valor == "" or valor == "[]": return 0
    try:
        import ast
        return len(ast.literal_eval(str(valor)))
    except: return 0

wc['cv1'] = wc['cartao_vermelho_1'].apply(extrair_contagem)
wc['cv2'] = wc['cartao_vermelho_2'].apply(extrair_contagem)
wc['ca1'] = wc['cartao_amarelo_1'].apply(extrair_contagem)
wc['ca2'] = wc['cartao_amarelo_2'].apply(extrair_contagem)

cartoes_ano = wc.groupby('ano').agg(
    amarelos=('ca1', 'sum'),
    amarelos_2=('ca2', 'sum'),
    vermelhos=('cv1', 'sum'),
    vermelhos_2=('cv2', 'sum')
)
cartoes_ano['Total Amarelos'] = cartoes_ano['amarelos'] + cartoes_ano['amarelos_2']
cartoes_ano['Total Vermelhos'] = cartoes_ano['vermelhos'] + cartoes_ano['vermelhos_2']

wc['gc1'] = wc['gols_1_contra'].apply(extrair_contagem)
wc['gc2'] = wc['gols_2_contra'].apply(extrair_contagem)
gols_contra_ano = wc.groupby('ano')[['gc1', 'gc2']].sum().sum(axis=1)

fig, axs = plt.subplots(2, 2, figsize=(18, 12))
plt.subplots_adjust(hspace=0.3, wspace=0.2)

axs[0, 0].bar(jogos_ano.index, jogos_ano.values, color='steelblue')
axs[0, 0].set_title('Quantidade de Jogos por Ano')
axs[0, 0].set_xlabel('Ano')
axs[0, 0].set_ylabel('Nº de Jogos')

axs[0, 1].stackplot(gols_ano.index, gols_ano['gols_1'], gols_ano['gols_2'], labels=['Gols Casa', 'Gols Visitante'], alpha=0.8)
axs[0, 1].set_title('Evolução de Gols por Ano (Empilhado)')
axs[0, 1].set_xlabel('Ano')
axs[0, 1].set_ylabel('Total de Gols')
axs[0, 1].legend(loc='upper left')

axs[1, 1].bar(gols_contra_ano.index, gols_contra_ano.values, color='indianred')
axs[1, 1].set_title('Total de Gols Contra por Ano')
axs[1, 1].set_xlabel('Ano')
axs[1, 1].set_ylabel('Gols Contra')

axs[1, 0].stackplot(cartoes_ano.index, cartoes_ano['Total Amarelos'], cartoes_ano['Total Vermelhos'], 
                    labels=['Amarelos', 'Vermelhos'], colors=['gold', 'red'], alpha=0.7)
axs[1, 0].set_title('Total de Cartões por Ano')
axs[1, 0].set_xlabel('Ano')
axs[1, 0].set_ylabel('Quantidade de Cartões')
axs[1, 0].legend(loc='upper left')

plt.show()
